# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Loding Dataset

# %%
df=pd.read_csv("shopping_behavior_updated.csv")

# %% [markdown]
# ##### Preview Data

# %%
df.sample(10)
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 2482         2483   69    Male        Handbag  Accessories
# 3711         3712   69  Female            Hat  Accessories
# 46             47   57    Male          Shirt     Clothing
# 1451         1452   54    Male         Jacket    Outerwear
# 198           199   57    Male        Jewelry  Accessories
# 998           999   51    Male          Shoes     Footwear
# 3790         3791   27  Female        Handbag  Accessories
# 3133         3134   58  Female        T-shirt     Clothing
# 1956         1957   70    Male          Socks     Clothing
# 1937         1938   43    Male          Socks     Clothing
#
#       Purchase Amount (USD)     Location Size      Color  Season  \
# 2482                     87      Arizona    S      Peach  Winter
# 3711                     62        Texas   XL      Peach    Fall
# 46                       43   California    L      White  Summer
# ...

# %% [markdown]
# ##### Check datatype and know about columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
# ...

# %% [markdown]
# ##### Summary of Dataset

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age Gender Item Purchased  Category  \
# count   3900.000000  3900.000000   3900           3900      3900
# unique          NaN          NaN      2             25         4
# top             NaN          NaN   Male         Blouse  Clothing
# freq            NaN          NaN   2652            171      1737
# mean    1950.500000    44.068462    NaN            NaN       NaN
# std     1125.977353    15.207589    NaN            NaN       NaN
# min        1.000000    18.000000    NaN            NaN       NaN
# 25%      975.750000    31.000000    NaN            NaN       NaN
# 50%     1950.500000    44.000000    NaN            NaN       NaN
# 75%     2925.250000    57.000000    NaN            NaN       NaN
# max     3900.000000    70.000000    NaN            NaN       NaN
#
#         Purchase Amount (USD) Location  Size  Color  Season  Review Rating  \
# count             3900.000000     3900  3900   3900    3900    3900.000000
# ...

# %% [markdown]
# ##### Check for null values

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %% [markdown]
# ##### Convert column_name into readable name

# %%
df.columns=df.columns.str.lower()
df.columns=df.columns.str.replace(' ','_')
df.rename(columns={"purchase_amount_(usd)":"purchase_amount"},inplace=True)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='object')

# %% [markdown]
# ##### Add new column that helps in analysis

# %%
#new column
labels=['Young','Adult','Middle-aged','Older']
df['age_group']=pd.qcut(df['age'],q=4,labels=labels)

# %%
df.sample(10)
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 3541         3542   59  Female         Blouse     Clothing               66
# 1200         1201   27    Male           Coat    Outerwear               22
# 3064         3065   22  Female           Belt  Accessories               76
# 3719         3720   20  Female          Pants     Clothing               91
# 3844         3845   30  Female         Shorts     Clothing               87
# 463           464   37    Male        Jewelry  Accessories               81
# 3815         3816   32  Female            Hat  Accessories               44
# 1276         1277   51    Male          Boots     Footwear               68
# 2845         2846   26  Female       Backpack  Accessories               77
# 3209         3210   64  Female          Shoes     Footwear               31
#
#           location size      color  season  review_rating subscription_status  \
# ...

# %%
# create frequency day column 

frequency_mapping={
    'Fortnightly':14,
    'Weekly':7,
    'Annually':365,
    'Quarterly':90,
    'Bi-Weekly':14,
    'Monthly':30,
    'Every 3 Months':90
}
df['frequency_of_purchases_day']=df['frequency_of_purchases'].map(frequency_mapping)
df[['frequency_of_purchases_day','frequency_of_purchases']].head(5)
# Out:
#    frequency_of_purchases_day frequency_of_purchases
# 0                          14            Fortnightly
# 1                          14            Fortnightly
# 2                           7                 Weekly
# 3                           7                 Weekly
# 4                         365               Annually

# %%
df.drop('promo_code_used',axis=1,inplace=True)
df
# Out:
#       customer_id  age  gender item_purchased     category  purchase_amount  \
# 0               1   55    Male         Blouse     Clothing               53
# 1               2   19    Male        Sweater     Clothing               64
# 2               3   50    Male          Jeans     Clothing               73
# 3               4   21    Male        Sandals     Footwear               90
# 4               5   45    Male         Blouse     Clothing               49
# ...           ...  ...     ...            ...          ...              ...
# 3895         3896   40  Female         Hoodie     Clothing               28
# 3896         3897   52  Female       Backpack  Accessories               49
# 3897         3898   46  Female           Belt  Accessories               33
# 3898         3899   44  Female          Shoes     Footwear               77
# 3899         3900   52  Female        Handbag  Accessories               81
#
# ...

# %% [markdown]
# ##### Save this dataset, Load into Power BI or do more transformation

# %%
df.to_csv('update_shopping.csv',index=False)
